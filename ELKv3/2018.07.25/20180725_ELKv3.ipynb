# %% [markdown]
# # 웹크롤링
# ## 다음 뉴스
#
# 주소따기
# https://www.daum.net/
# http://media.daum.net/ : 뉴스
# http://media.daum.net/issue/ : 전체 이슈보기
#
# http://media.daum.net/issue/all/1 : 실시간 주요이슈 목록 전체

# %%
#HTTP를 처리하기 위한 라이브러리
import urllib.request
from urllib.request import urlretrieve

#requests 라이브러리 기반으로 코드 작성하지 말것!!!
#import requests
import time

#HTML을 처리하기 위한 라이브러리
from bs4 import BeautifulSoup
import pandas as pd

# %%
webpage = urllib.request.urlopen('http://m.media.daum.net/m/media/')
ori_contents = webpage.read().decode("utf-8")
contents = BeautifulSoup(ori_contents, "lxml")
contents
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="다음뉴스" property="og:title"/>
# <meta content="//t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스 모바일" property="og:description"/>
# <meta content="http://m.media.daum.net/m/media/" property="og:url"/>
# <meta content="m.media.daum.net" name="svcdomain"/>
# <link href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, width=device-width, viewport-fit=cover" name="viewport">
# <meta content="telephone=no" name="format-detection">
# <link href="//t1.daumcdn.net/media/news/og/apple-icon-120x120.png?20180628" rel="apple-touch-icon-precomposed">
# ...

# %%
webpage = urllib.request.urlopen('http://media.daum.net/issue/all/1')
ori_contents = webpage.read().decode("utf-8")
contents = BeautifulSoup(ori_contents, "html.parser")
contents
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="Daum 뉴스" property="og:author">
# <meta content="다음뉴스" property="og:site_name">
# <meta content="이슈" property="og:title"/>
# <meta content="//t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="http://media.daum.net/issue/all/1" property="og:url"/>
# <meta content="media.daum.net" name="svcdomain"/>
# <title>이슈 | 다음뉴스</title>
# <link href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <link href="//t1.daumcdn.net/media/static/media-801/dist/news/css/common.min.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/static/media-801/dist/news/css/news.min.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 7]>
# ...

# %%
txtIssueContents = contents.find_all("a", attrs={'class': 'link_txt'})

# %%
contents.find_all("a", attrs={'class': 'link_txt'})dd
# Out:
# [<a class="link_txt #RIGHT#popular_news#news_list @1" href="http://v.media.daum.net/v/20180724154212444">
#                                      故노회찬 빈소서 오열한 조국 청와대 민정수석
#                                  </a>,
#  <a class="link_txt #RIGHT#popular_news#news_list @2" href="http://v.media.daum.net/v/20180724150617597">
#                                      밤새 에어컨 틀었는데 이달 전기요금 얼마나 나올까
#                                  </a>,
#  <a class="link_txt #RIGHT#popular_news#news_list @3" href="http://v.media.daum.net/v/20180724150252465">
#                                      화염 피해 아이 2명 안고 창문에 매달려 버틴 30대 가장
#                                  </a>,
#  <a class="link_txt #RIGHT#popular_news#news_list @4" href="http://v.media.daum.net/v/20180724175726621">
#                                      라오스에서 수력발전소 댐 붕괴..수백명 사망·실종
#                                  </a>,
#  <a class="link_txt #RIGHT#popular_news#news_list @5" href="http://v.media.daum.net/v/20180724183744164">
# ...

# %%
txtIssueContents[0]
# Out:
# <a class="link_txt #RIGHT#popular_news#news_list @1" href="http://v.media.daum.net/v/20180724154212444">
#                                     故노회찬 빈소서 오열한 조국 청와대 민정수석
#                                 </a>

# %%
len(txtIssueContents)
# Out:
# 110

# %%
txtIssueContents[0]["href"]
# Out:
# 'http://v.media.daum.net/v/20180724154212444'

# %%
txtIssueContents[0]["href"][:4]
# Out:
# 'http'

# %%
for txtIssue in txtIssueContents:
#     print(txtIssue["href"])

#     print(txtIssue.text.strip().find("노회찬"))
#     print(txtIssue.text.strip())
    
    if txtIssue.text.strip().find("노회찬") > 0:
        print(txtIssue.text.strip())
#     if txtIssue[:4] is not 'http':
#         print(txtIssue)
# Out:
# 故노회찬 빈소서 오열한 조국 청와대 민정수석
# 드루킹 "노회찬에 불법 정치자금 줬다"..특검서 실토
# "아까운 정치인 잃어" 노회찬 빈소에 어제 하루 3천명 조문
# 눈물 흘린 보수.. 노회찬 빈소 안팎의 한 풍경
# 이정미 "노회찬 원통한 죽음, 책임 반드시 묻게 될 것"

# %%
daumurl = r"http://m.media.daum.net/proxy/api/mc2/contents/find.json?page=1&pageSize=100&service=news&clusterType=important&range=5"
webpage = urllib.request.urlopen(daumurl)
ori_contents = json.loads(webpage.read().decode("utf-8"))
ori_contents
# Out:
# {'countPerPage': 100,
#  'currentCount': 100,
#  'currentPage': 1,
#  'data': [{'_id': {'key': '20180724205207997', 'type': 'news'},
#    'author': {'reporter': '한동수'},
#    'cateInfo': {'cateId': '1046',
#     'category': 'foreign',
#     'name': '국제일반',
#     'service': 'news'},
#    'cluster': [{'collectionName': 'clusters', 'databaseName': None, 'id': 426},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 427},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 129824},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 594222},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 857658},
#     {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
# ...

# %%
ori_contents['data']
# Out:
# [{'_id': {'key': '20180724205207997', 'type': 'news'},
#   'author': {'reporter': '한동수'},
#   'cateInfo': {'cateId': '1046',
#    'category': 'foreign',
#    'name': '국제일반',
#    'service': 'news'},
#   'cluster': [{'collectionName': 'clusters', 'databaseName': None, 'id': 426},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 427},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 129824},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 594222},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 857658},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#    {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
# ...

# %%
ori_contents['data'][0]
# Out:
# {'_id': {'key': '20180724205207997', 'type': 'news'},
#  'author': {'reporter': '한동수'},
#  'cateInfo': {'cateId': '1046',
#   'category': 'foreign',
#   'name': '국제일반',
#   'service': 'news'},
#  'cluster': [{'collectionName': 'clusters', 'databaseName': None, 'id': 426},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 427},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 129824},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 594222},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857658},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
# ...

# %%
len(ori_contents['data'])
# Out:
# 100

# %%
news = ori_contents['data'][0]

# %%
news
# Out:
# {'_id': {'key': '20180724205207997', 'type': 'news'},
#  'author': {'reporter': '한동수'},
#  'cateInfo': {'cateId': '1046',
#   'category': 'foreign',
#   'name': '국제일반',
#   'service': 'news'},
#  'cluster': [{'collectionName': 'clusters', 'databaseName': None, 'id': 426},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 427},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 129824},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 594222},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857658},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
# ...

# %%
news['author']
# Out:
# {'reporter': '한동수'}

# %%
news['author']['reporter']
# Out:
# '한동수'

# %%
news
# Out:
# {'_id': {'key': '20180724205207997', 'type': 'news'},
#  'author': {'reporter': '한동수'},
#  'cateInfo': {'cateId': '1046',
#   'category': 'foreign',
#   'name': '국제일반',
#   'service': 'news'},
#  'cluster': [{'collectionName': 'clusters', 'databaseName': None, 'id': 426},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 427},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 129824},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 594222},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857658},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 857519},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848418},
# ...

# %%
del news['cluster']
셀 합치기 단축키(안)

# %%
news
# Out:
# {'_id': {'key': '20180724205207997', 'type': 'news'},
#  'author': {'reporter': '한동수'},
#  'cateInfo': {'cateId': '1046',
#   'category': 'foreign',
#   'name': '국제일반',
#   'service': 'news'},
#  'cpInfo': {'engName': 'imbc',
#   'id': '98',
#   'korName': 'MBC',
#   'outlink': 'http://imnews.imbc.com/replay/2018/nwdesk/article/4715148_22663.html'},
#  'description': ' ◀ 앵커 ▶ SK건설이 라오스에서 시공 중인 대형 수력 발전댐의 보조댐이 붕괴됐습니다. 댐이 무너지면서 가둬놨던 물이 댐 아래 6개 마을을 덮치면서 수백 명이 실종되고 6천 명 넘는 이재민이 발생했습니다. 한동수 기자입니다. ◀ 리포트 ▶ 무너진 댐 사이로 거대한 물줄기가 쉴 새 없이 쏟아집니다. 어젯밤 라오스 남동부 세피안·세남노이 수력발',
#  'etcInfo': {'license': ['buzz_launcher', 'kakaotalk_channel', 'mobile.web']},
#  'factor': {'important': 'true',
#   'newsType': '2',
#   'orgId': 'g2t88xef6a',
#   'status': 'S',
#   'whitelist': 'true'},
#  'image': ['https://t1.daumcdn.net/news/201807/24/imbc/20180724205207045jhia.jpg'],
#  'keyword': ['라오스', '실종', '홍수', '붕괴', 'sk건설'],
#  'modiDt': 1532433356000,
#  'ranking': {'commentCount': 1, 'playCount': 0},
# ...

# %%
for jsonNews in ori_contents['data']:
#     print(jsonNews['_id']['type'] + " : " + jsonNews['_id']['key'])
#     print(jsonNews['author']['reporter'])
#     print(jsonNews['cateInfo']['name'])
    print(jsonNews['description'])
# Out:
#  ◀ 앵커 ▶ SK건설이 라오스에서 시공 중인 대형 수력 발전댐의 보조댐이 붕괴됐습니다. 댐이 무너지면서 가둬놨던 물이 댐 아래 6개 마을을 덮치면서 수백 명이 실종되고 6천 명 넘는 이재민이 발생했습니다. 한동수 기자입니다. ◀ 리포트 ▶ 무너진 댐 사이로 거대한 물줄기가 쉴 새 없이 쏟아집니다. 어젯밤 라오스 남동부 세피안·세남노이 수력발
# <앵커> 실제 이 재판은 문건 내용대로 공판이 재개됐습니다. 스폰서 판사 의혹을 축소 은폐했다는 의혹을 받았던 법원행정처가 해당 판사의 또 다른 비리 정황도 무마하려고 재판에까지 개입하려 한 것 아니냐는 의심이 짙어지고 있습니다. 임찬종 기자가 단독 취재했습니다.  <기자> 2016년 법원행정처 문건에 나오는 대책은 문모 판사의 스폰서로 지목된 업자 정 모
# <앵커> 부산 스폰서 판사 의혹에 대해 그제(22일) 보도해 드렸는데 법원행정처가 이 사건 관련 재판에 개입한 정황이 검찰에 포착됐습니다. 업자로부터 접대받는다는 의혹이 제기됐던 판사가 해당 업자가 기소된 재판 정보를 빼낸 정황이 있었는데 이걸 알게 된 법원행정처가 재판 절차에 개입하려 했다는 내용입니다. 먼저 김기태 기자의 단독 보도입니다. <기자> 검찰
#  고 노회찬 정의당 원내 대표의 갑작스러운 죽음은 아직도 많은 이들을 충격에서 벗어나지 못하게 하고 있는 것 같습니다. 빈소가 차려진 신촌 세브란스 병원에 조문 행렬이 오늘(24일)도 이어지고 있습니다. 현장에 나가 있는 김필준 기자 잠깐 연결하겠습니다. 김필준 기자, 지금 조문객들의 줄이 빈소를 한 바퀴 돌 정도로 길다는데 좀 전해주시죠. [기자]
#  외교부는 24일 라오스 세남노이 지역에서 SK건설 등이 시공 중인 수력발전 보조댐이 붕괴한 사고와 관련해 현재까지 확인된 우리 국민 피해는 없다고 밝혔다, 외교부 당국자는 "주라오스 대사관은 사고 인지 직후 현장상황반을 구성하고 영사협력원, 해당 건설업체, 교민 네트워크 등을 통해 우리 국민 피해를 파악했다"며 "현재까지
# ...

# %%
ori_contents['data'][1]
# Out:
# {'_id': {'key': '20180724205102976', 'type': 'news'},
#  'author': {'reporter': '임찬종 기자'},
#  'cateInfo': {'cateId': '1067',
#   'category': 'society',
#   'name': '사회일반',
#   'service': 'news'},
#  'cluster': [{'collectionName': 'clusters', 'databaseName': None, 'id': 437},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 438},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 129824},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848421},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 787344},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 848421},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 735628},
#   {'collectionName': 'clusters', 'databaseName': None, 'id': 578584}],
#  'cpInfo': {'engName': 'sbsi',
#   'id': '73',
#   'korName': 'SBS',
# ...

# %%
demoNews = pd.DataFrame()


for jsonNews in ori_contents['data']:
    jsonNews['cpInfo']['korName']
    jsonNews['title']
    jsonNews['description']
    jsonNews['cpInfo']['outlink']

# %%
from pandas import Series, DataFrame

# %%
demoNews = DataFrame(ori_contents['data'])
demoNews
# Out:
#                                              _id  \
# 0   {'type': 'news', 'key': '20180724205207997'}
# 1   {'type': 'news', 'key': '20180724205102976'}
# 2   {'type': 'news', 'key': '20180724204803909'}
# 3   {'type': 'news', 'key': '20180724204346798'}
# 4   {'type': 'news', 'key': '20180724204230785'}
# 5   {'type': 'news', 'key': '20180724204202778'}
# 6   {'type': 'news', 'key': '20180724204102758'}
# 7   {'type': 'news', 'key': '20180724203520663'}
# 8   {'type': 'news', 'key': '20180724203516661'}
# 9   {'type': 'news', 'key': '20180724203303603'}
# 10  {'type': 'news', 'key': '20180724203137569'}
# 11  {'type': 'news', 'key': '20180724203117561'}
# 12  {'type': 'news', 'key': '20180724203116559'}
# 13  {'type': 'news', 'key': '20180724203106549'}
# 14  {'type': 'news', 'key': '20180724203002534'}
# 15  {'type': 'news', 'key': '20180724202702478'}
# 16  {'type': 'news', 'key': '20180724202605454'}
# 17  {'type': 'news', 'key': '20180724202517436'}
# ...

# %%
demoNews['_id'][0]['key']
# Out:
# '20180724205207997'

# %%
n = 0

for key in demoNews['_id']:
#     print(key['key'])
    demoNews['_id'][n] = key['key']
    n = n + 1
    
demoNews
# Out:
# E:\Program\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                   _id                          author  \
# 0   20180724205207997             {'reporter': '한동수'}
# 1   20180724205102976          {'reporter': '임찬종 기자'}
# 2   20180724204803909          {'reporter': '김기태 기자'}
# 3   20180724204346798             {'reporter': '김필준'}
# 4   20180724204230785                {'reporter': ''}
# 5   20180724204202778          {'reporter': '민경호 기자'}
# 6   20180724204102758                {'reporter': ''}
# 7   20180724203520663                {'reporter': ''}
# 8   20180724203516661             {'reporter': '강다운'}
# 9   20180724203303603          {'reporter': '김혜영 기자'}
# 10  20180724203137569             {'reporter': '정재우'}
# ...

# %%
n = 0

for key in demoNews['author']:
#     print(key['key'])
    demoNews['author'][n] = key['reporter']
    n = n + 1
    
demoNews
# Out:
# E:\Program\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                   _id          author  \
# 0   20180724205207997             한동수
# 1   20180724205102976          임찬종 기자
# 2   20180724204803909          김기태 기자
# 3   20180724204346798             김필준
# 4   20180724204230785
# 5   20180724204202778          민경호 기자
# 6   20180724204102758
# 7   20180724203520663
# 8   20180724203516661             강다운
# 9   20180724203303603          김혜영 기자
# 10  20180724203137569             정재우
# 11  20180724203117561             최형문
# 12  20180724203116559             박민주
# 13  20180724203106549             박영회
# 14  20180724203002534          조재근 기자
# 15  20180724202702478          김흥수 기자
# 16  20180724202605454
# 17  20180724202517436             서효정
# ...

# %%
demoNews.to_excel('demoNews.xls')
demoNews.to

# %%
demoDFrame = DataFrame(columns=('news_id', 'author', 'cpinfo_korname', 'cpuinfo_outlink'))

# %%
demoDFrame
# Out:
# Empty DataFrame
# Columns: [news_id, author, cpinfo_korname, cpuinfo_outlink]
# Index: []

# %%
demoFrame
