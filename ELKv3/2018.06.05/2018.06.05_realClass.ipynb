# %%
#HTTP를 처리하기 위한 라이브러리
import urllib.request
from urllib.request import urlretrieve

#requests 라이브러리 기반으로 코드 작성하지 말것!!!
#import requests
import time

#HTML을 처리하기 위한 라이브러리
from bs4 import BeautifulSoup
import pandas as pd

# %%
webpage = urllib.request.urlopen('http://media.daum.net/breakingnews/society/environment?page=5')
ori_contents = webpage.read().decode("utf-8")
ori_contents
# Out:
# '\n<!doctype html>\n<html lang="ko">\n<head>\n\n\t<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\n\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="전체 뉴스"/>\n<meta property="og:image" content="http://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<meta property="og:url" content="http://media.daum.net/breakingnews/society/environment?page=5"/>\n\n<meta name="svcdomain" content="media.daum.net" />\n\n<title>전체 뉴스 | 다음뉴스</title>\n\n\n<link rel="shortcut icon" href="http://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<link rel="stylesheet" type="text/css" href="http://t1.daumcdn.net/media/static/media-656/dist/news/css/common.min.css">\n<link rel="stylesheet" type="text/css" href="http://t1.daumcdn.net/media/static/media-656/dist/news/css/news.min.css">\n\n<!--[if lte IE 7]>\n<script type="text/javasc
# ...

# %%
contents = BeautifulSoup(ori_contents, "html.parser")
contents
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="Daum 뉴스" property="og:author">
# <meta content="다음뉴스" property="og:site_name">
# <meta content="전체 뉴스" property="og:title"/>
# <meta content="http://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="http://media.daum.net/breakingnews/society/environment?page=5" property="og:url"/>
# <meta content="media.daum.net" name="svcdomain"/>
# <title>전체 뉴스 | 다음뉴스</title>
# <link href="http://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <link href="http://t1.daumcdn.net/media/static/media-656/dist/news/css/common.min.css" rel="stylesheet" type="text/css"/>
# <link href="http://t1.daumcdn.net/media/static/media-656/dist/news/css/news.min.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 7]>
# ...

# %%
contents.find_all("div", attrs={'class': 'cont_thumb'})
# Out:
# [<div class="cont_thumb">
#  <strong class="tit_thumb">
#  <a class="link_txt" href="http://v.media.daum.net/v/20180604155116156">작살로 밍크고래 17마리 포획..포경선 선주들 실형·집유</a>
#  <span class="info_news">연합뉴스<span class="txt_bar"> · </span><span class="info_time">15:51</span></span>
#  </strong>
#  <div class="desc_thumb">
#  <span class="link_txt">
#                                      (울산=연합뉴스) 허광무 기자 = 작살로 밍크고래를 불법 포획한 포경선의 선주 2명에게 징역형과 징역형의 집행유예가 각각 선고됐다. 울산지법 형사3단독 김주옥 부..
#                                  </span><!-- 말줄임 처리 필요 -->
#  </div>
#  </div>, <div class="cont_thumb">
#  <strong class="tit_thumb">
#  <a class="link_txt" href="http://v.media.daum.net/v/20180604154200825">수족관 돌고래 '방류vs유지'..울산시장 후보들 입장 달라</a>
#  <span class="info_news">파이낸셜뉴스<span class="txt_bar"> · </span><span class="info_time">15:42</span></span>
#  </strong>
#  <div class="desc_thumb">
#  <span class="link_txt">
# ...

# %%
len(contents.find_all("div", attrs={'class': 'cont_thumb'}))
# Out:
# 17

# %%
contents.find_all("div", attrs={'class': 'cont_thumb'})[5]
# Out:
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="http://v.media.daum.net/v/20180604151321802">6월5일 환경의 날, 상암동 문화비축기지 기념행사</a>
# <span class="info_news">파이낸셜뉴스<span class="txt_bar"> · </span><span class="info_time">15:13</span></span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                                     환경부는 오는 5일 서울 마포구 문화비축기지에서 이낙연 국무총리, 김은경 환경부 장관 등 800여명이 참석한 가운데 ‘제23회 환경의 날 기념식’을 개최한다고 4..
#                                 </span><!-- 말줄임 처리 필요 -->
# </div>
# </div>

# %%
elements = contents.find_all("div", attrs={'class': 'cont_thumb'})

# %%
for element in elements:
    print(element)
# Out:
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="http://v.media.daum.net/v/20180604155116156">작살로 밍크고래 17마리 포획..포경선 선주들 실형·집유</a>
# <span class="info_news">연합뉴스<span class="txt_bar"> · </span><span class="info_time">15:51</span></span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                                     (울산=연합뉴스) 허광무 기자 = 작살로 밍크고래를 불법 포획한 포경선의 선주 2명에게 징역형과 징역형의 집행유예가 각각 선고됐다. 울산지법 형사3단독 김주옥 부..
#                                 </span><!-- 말줄임 처리 필요 -->
# </div>
# </div>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="http://v.media.daum.net/v/20180604154200825">수족관 돌고래 '방류vs유지'..울산시장 후보들 입장 달라</a>
# <span class="info_news">파이낸셜뉴스<span class="txt_bar"> · </span><span class="info_time">15:42</span></span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
# ...

# %%
element = contents.find_all("div", attrs={'class': 'cont_thumb'})[0]
element
# Out:
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" href="http://v.media.daum.net/v/20180604155116156">작살로 밍크고래 17마리 포획..포경선 선주들 실형·집유</a>
# <span class="info_news">연합뉴스<span class="txt_bar"> · </span><span class="info_time">15:51</span></span>
# </strong>
# <div class="desc_thumb">
# <span class="link_txt">
#                                     (울산=연합뉴스) 허광무 기자 = 작살로 밍크고래를 불법 포획한 포경선의 선주 2명에게 징역형과 징역형의 집행유예가 각각 선고됐다. 울산지법 형사3단독 김주옥 부..
#                                 </span><!-- 말줄임 처리 필요 -->
# </div>
# </div>

# %%
element('a')
# Out:
# [<a class="link_txt" href="http://v.media.daum.net/v/20180604155116156">작살로 밍크고래 17마리 포획..포경선 선주들 실형·집유</a>]

# %%
element.select_one('.link_txt')
# Out:
# <a class="link_txt" href="http://v.media.daum.net/v/20180604155116156">작살로 밍크고래 17마리 포획..포경선 선주들 실형·집유</a>

# %%
element.select_one('.link_txt').attrs.get('href')
# Out:
# 'http://v.media.daum.net/v/20180604155116156'

# %%
element.select_one('.link_txt').text
# Out:
# '작살로 밍크고래 17마리 포획..포경선 선주들 실형·집유'

# %%
element.select_one('.info_news')
# Out:
# <span class="info_news">연합뉴스<span class="txt_bar"> · </span><span class="info_time">15:51</span></span>

# %%
element.select_one('.info_news').text
# Out:
# '연합뉴스 · 15:51'

# %%
element.select_one('.info_news').text.split(' ')
# Out:
# ['연합뉴스', '·', '15:51']

# %%
element.select_one('.info_news').text.split(' ')[0]
# Out:
# '연합뉴스'

# %% [raw]
# 뉴스제목, URL, 매체, 요약
#
# ......
# (이후 시간이 없어서 준비한 코드로 진행함.)
